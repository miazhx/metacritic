# %% [markdown]
# # Getting Started

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('metacri_reviews_final.csv')

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
import re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\miazh_000\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\miazh_000\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from nltk.tokenize import word_tokenize
from textblob import TextBlob
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
from nltk import WordNetLemmatizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
df.dtypes
# Out:
# critic_name               object
# distributor               object
# genre                    float64
# individual_meta_score      int64
# media                     object
# meta_mixed               float64
# meta_negative            float64
# meta_positive            float64
# metascore                  int64
# movie_title               object
# release_date              object
# review_date               object
# text                      object
# userscore                 object
# dtype: object

# %%
df.shape
# Out:
# (247009, 14)

# %% [markdown]
# # Graph 1 - Metacritic Review Summary

# %%
df_review= pd.read_csv('metacri_reviews_final.csv') 
df_review = df_review[['review_date','individual_meta_score']].dropna(axis=0, how='any')
df_review['review_date'] = pd.to_datetime(df_review['review_date'])
df_review = df_review.set_index('review_date')

# %%
graph_1 = df_review.groupby(df_review.index.map(lambda x: x.year)).agg({'individual_meta_score':['count']}).plot.bar(color='#7393BC', width = 0.5)

graph_1.legend(["Review", ""])

# %% [markdown]
# # Data Cleaning

# %%
### drop nan values 
df = df.drop(['genre','meta_mixed','meta_negative','meta_positive'],1).dropna(axis=0, how='any')

# %%
df_critics = df.groupby(['media','critic_name']).agg({'individual_meta_score':['mean','count']})

# %%
df['text'] = df['text'].str.lower()
df['text'] = df['text'].apply(lambda x: re.sub('\s+', ' ', x))

# %%
df['text'] = df['text'].apply(lambda x: re.sub('[^\w\s]', '', x))

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')+['movie','make','film','one','even','films','movies','way','makes','made','thats']
df['text'] = df['text'].apply(lambda text: " ".join(word for word in text.split() if word not in stop))

# %%
df['review_date'] = pd.to_datetime(df['review_date'])

# %% [markdown]
# # Word Cloud

# %%
#df['release_date'] = pd.to_datetime(df['release_date'])
mask1 = (df['review_date'] > '1/1/2009') & (df['review_date'] <= '1/1/2019') & (df['metascore'] > 70)
mask2 = (df['review_date'] > '1/1/2009') & (df['review_date'] <= '1/1/2019') & (df['metascore'] < 30)
mask3 = (df['review_date'] > '1/1/2009') & (df['review_date'] <= '1/1/2019') & (df['metascore'] > 30) & (df['metascore'] < 70)

# %%
wc1 = WordCloud(background_color="white", max_words=2000, width=1600, height=800)
# generate word cloud
wc1.generate(' '.join(df.loc[mask1]['text']))
plt.figure(figsize=(12, 6))
plt.imshow(wc1, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wc2 = WordCloud(background_color="white", max_words=800, width=1600, height=800)
# generate word cloud
wc2.generate(' '.join(df.loc[mask2]['text']))
plt.figure(figsize=(12, 6))
plt.imshow(wc2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# wc3 = WordCloud(background_color="white", max_words=2000, width=800, height=400)
# # generate word cloud
# wc.generate(' '.join(df.loc[mask3]['text']))
# plt.figure(figsize=(12, 6))
# plt.imshow(wc3, interpolation='bilinear')
# plt.axis("off")
# plt.show()

# %% [markdown]
# # Sentiment Analysis

# %%
df_positive = df.loc[df.individual_meta_score > 60]
df_negative = df.loc[df.individual_meta_score < 40]
sample_size = 2000

def sentiment_func(x):
    sentiment = TextBlob(x['text'])
    x['polarity'] = sentiment.polarity
    x['subjectivity'] = sentiment.subjectivity
    return x

sample_1 = df_positive.sample(sample_size).apply(sentiment_func, axis=1)
sample_2 = df_negative.sample(sample_size).apply(sentiment_func, axis=1)


sample_1.plot.scatter('individual_meta_score', 'polarity')

# %%
sample_2.plot.scatter('individual_meta_score', 'polarity')

# %% [markdown]
# # Media

# %%
#### Matplotlib

# %matplotlib inline 
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
df_graph_1 = df.groupby([df['review_date'].map(lambda x: x.year),'media']).agg({'individual_meta_score':['mean','count']})
df_graph_1
# Out:
#                                          individual_meta_score
#                                                           mean count
# review_date media
# 2010        Arizona Republic                         70.333333    30
#             Austin Chronicle                         55.317073    41
#             Boston Globe                             60.964912    57
#             Charlotte Observer                       66.500000    10
#             Chicago Reader                           61.777778    45
#             Chicago Sun-Times                        75.227273    44
#             Chicago Tribune                          64.405405    37
#             Christian Science Monitor                65.733333    45
#             Empire                                   62.500000    16
#             Entertainment Weekly                     72.203390    59
#             L.A. Weekly                              50.000000     3
#             Los Angeles Times                        62.388060    67
#             Miami Herald                             61.153846    26
#             NPR                                      69.790698    43
#             New Orleans Times-Picayune               70.826087    23
#             New York Daily News                      54.782609    69
#             New York Magazine (Vulture)              62.727273    22
#             New York Post                            54.324324    74
#             Observer                                 64.695652    23
#             Orlando Sentinel                         63.204545    44
#             Philadelphia Inquirer                    73.577778    45
#             Portland Oregonian                       70.838710    31
#             ReelViews                                66.285714    35
#             Rolling Stone                            67.028571    35
#             Salon                                    66.285714    35
#             San Francisco Chronicle                  62.500000    60
#             Slate                                    54.736842    19
#             St. Louis Post-Dispatch                  66.250000    32
#             Tampa Bay Times                          66.413793    29
#             The A.V. Club                            62.597015    67
# ...                                                        ...   ...
# 2019        ScreenCrush                              61.212121    33
#             Slant Magazine                           58.197674   258
#             Slate                                    65.000000    48
#             TV Guide Magazine                        88.000000     1
#             The A.V. Club                            64.868726   259
#             The Associated Press                     64.372549   102
#             The Atlantic                             66.544118    68
#             The Globe and Mail (Toronto)             65.486111   144
#             The Guardian                             61.302682   261
#             The Hollywood Reporter                   61.617647   340
#             The New York Times                       62.188366   361
#             The New Yorker                           63.846154    78
#             The Observer (UK)                        64.081633   147
#             The Playlist                             67.040609   197
#             The Seattle Times                        68.629213    89
#             The Telegraph                            64.141414    99
#             The Verge                                70.766667    30
#             TheWrap                                  68.288462   260
#             Time                                     67.543860    57
#             Time Out                                 66.400000   100
#             Total Film                               70.208333    48
#             USA Today                                69.771429    35
#             Uproxx                                   68.073171    41
#             Vanity Fair                              64.090909    66
#             Variety                                  65.281250   320
#             Village Voice                            80.000000     1
#             Vox                                      66.206897    58
#             Wall Street Journal                      66.352941    85
#             Washington Post                          64.817073   164
#             We Got This Covered                      66.444444    45
#
# [513 rows x 2 columns]

# %%
years = df_graph_1.index.get_level_values(0).tolist()
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
year_list = df_date.index.year.unique().tolist()
year_list.sort()
year_list

# %% [markdown]
# # Critic's Review Quantity

# %%
# !pip install plotly_express
# !pip install --upgrade plotly
import plotly
plotly.offline.init_notebook_mode(connected=True)
import plotly.graph_objects as go
from plotly.graph_objs import Figure, Histogram, Layout

import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_graph_3 = df.groupby(df['critic_name']).agg({'individual_meta_score':['count','mean']})

# %%
df_temp = df[['critic_name', 'individual_meta_score']]

# %%
res1 = df_temp.groupby('critic_name').agg(['count', 'mean'])

# %%
df_mean = pd.Series(res1.unstack()['individual_meta_score']['mean'], name = 'mean_score')

# %%
df_count = pd.Series(res1.unstack()['individual_meta_score']['count'], name = 'count')
pd.concat([df_mean, df_count], axis=1)
pd_combined.plot.scatter(x = 'count', y = 'mean_score', )

# %%
plt.figure(figsize=(16,8))
plt.scatter(pd_combined['count'], pd_combined['mean_score'])
plt.xscale('log')
# plt.xlim(0, 500)
# plt.ylim(-1, 1)

# %% [markdown]
# # Review Date Analysis

# %%
import plotly.express as px

df_joker = df.loc[df.movie_title=='Joker',:].sort_values('review_date')
df_joker.groupby(df['review_date'])

# %%
fig = px.scatter(df_joker, x="review_date", y="individual_meta_score",marginal_x="histogram",marginal_y="histogram",size='individual_meta_score')
 
fig.update_layout(title = 'Joker')


fig.show()
# Out:
# <div>
#
#
#             <div id="df4a2652-1f45-49c3-ab38-9f34ea650b1f" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("df4a2652-1f45-49c3-ab38-9f34ea650b1f")) {
#                     Plotly.newPlot(
#                         'df4a2652-1f45-49c3-ab38-9f34ea650b1f',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "review_date=%{x}<br>individual_meta_score=%{marker.size}", "legendgroup": "", "marker": {"color": "#636efa", "size": [20, 55, 58, 60, 70, 80, 83, 90, 90, 80, 100, 100, 100, 100, 100, 67, 38, 50, 50, 40, 90, 75, 30, 90, 75, 30, 50, 63, 80, 50, 50, 30, 88, 60, 63, 38, 88, 45, 30, 40, 30, 63, 50, 20, 100, 50, 78, 83, 20, 100, 80, 88, 88], "sizemode": "area", "sizeref": 0.25, "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": ["2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-09-10T00:00:00", "2019-09-10T00:00:00", "2019-09-11T00:00:00", "2019-09-12T00:00:00", "2019-09-12T00:00:00", "2019-09-12T00:00:00", "2019-09-27T00:00:00", "2019-09-30T00:00:00", "2019-09-30T00:00:00", "2019-09-30T00:00:00", "2019-10-01T00:00:00", "2019-10-01T00:00:00", "2019-10-01T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-04T00:00:00", "2019-10-04T00:00:00", "2019-10-04T00:00:00", "2019-10-04T00:00:00", "2019-10-06T00:00:00", "2019-10-07T00:00:00", "2019-10-09T00:00:00"], "xaxis": "x", "y": [20, 55, 58, 60, 70, 80, 83, 90, 90, 80, 100, 100, 100, 100, 100, 67, 38, 50, 50, 40, 90, 75, 30, 90, 75, 30, 50, 63, 80, 50, 50, 30, 88, 60, 63, 38, 88, 45, 30, 40, 30, 63, 50, 20, 100, 50, 78, 83, 20, 100, 80, 88, 88], "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "review_date=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-08-31T00:00:00", "2019-09-10T00:00:00", "2019-09-10T00:00:00", "2019-09-11T00:00:00", "2019-09-12T00:00:00", "2019-09-12T00:00:00", "2019-09-12T00:00:00", "2019-09-27T00:00:00", "2019-09-30T00:00:00", "2019-09-30T00:00:00", "2019-09-30T00:00:00", "2019-10-01T00:00:00", "2019-10-01T00:00:00", "2019-10-01T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-02T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-03T00:00:00", "2019-10-04T00:00:00", "2019-10-04T00:00:00", "2019-10-04T00:00:00", "2019-10-04T00:00:00", "2019-10-06T00:00:00", "2019-10-07T00:00:00", "2019-10-09T00:00:00"], "xaxis": "x3", "yaxis": "y3"}, {"alignmentgroup": "True", "bingroup": "y", "hoverlabel": {"namelength": 0}, "hovertemplate": "individual_meta_score=%{y}<br>count=%{x}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "xaxis": "x2", "y": [20, 55, 58, 60, 70, 80, 83, 90, 90, 80, 100, 100, 100, 100, 100, 67, 38, 50, 50, 40, 90, 75, 30, 90, 75, 30, 50, 63, 80, 50, 50, 30, 88, 60, 63, 38, 88 ...
#                         {"barmode": "overlay", "height": 600, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type

# %%
import random

random_name = random.choice(df.movie_title.tolist())
print(random_name)

df.ramdom = df.loc[df.movie_title==random.choice(df.movie_title.tolist()),:]
fig = px.scatter(df.ramdom, x="review_date", y="individual_meta_score",marginal_x="histogram",marginal_y="histogram",size='individual_meta_score')
 
fig.update_layout(title = random_name)
fig.show()
# Out:
# The Eyes of My Mother
# <div>
#
#
#             <div id="327ae08d-db96-4b22-9ba0-dae94452800c" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("327ae08d-db96-4b22-9ba0-dae94452800c")) {
#                     Plotly.newPlot(
#                         '327ae08d-db96-4b22-9ba0-dae94452800c',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "review_date=%{x}<br>individual_meta_score=%{marker.size}", "legendgroup": "", "marker": {"color": "#636efa", "size": [70, 70, 68, 65, 63, 63, 60, 60, 60, 58, 50, 50, 50, 50, 50, 50, 40, 40, 40, 38, 30, 25, 20, 20, 12], "sizemode": "area", "sizeref": 0.175, "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": ["2017-09-13T00:00:00", "2017-09-13T00:00:00", "2017-09-14T00:00:00", "2017-09-13T00:00:00", "2017-09-15T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-12T00:00:00", "2017-09-14T00:00:00", "2017-09-17T00:00:00", "2017-09-17T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-13T00:00:00", "2017-09-20T00:00:00", "2017-09-13T00:00:00", "2017-09-13T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-13T00:00:00", "2017-09-14T00:00:00"], "xaxis": "x", "y": [70, 70, 68, 65, 63, 63, 60, 60, 60, 58, 50, 50, 50, 50, 50, 50, 40, 40, 40, 38, 30, 25, 20, 20, 12], "yaxis": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "review_date=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["2017-09-13T00:00:00", "2017-09-13T00:00:00", "2017-09-14T00:00:00", "2017-09-13T00:00:00", "2017-09-15T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-12T00:00:00", "2017-09-14T00:00:00", "2017-09-17T00:00:00", "2017-09-17T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-13T00:00:00", "2017-09-20T00:00:00", "2017-09-13T00:00:00", "2017-09-13T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-14T00:00:00", "2017-09-13T00:00:00", "2017-09-14T00:00:00"], "xaxis": "x3", "yaxis": "y3"}, {"alignmentgroup": "True", "bingroup": "y", "hoverlabel": {"namelength": 0}, "hovertemplate": "individual_meta_score=%{y}<br>count=%{x}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "xaxis": "x2", "y": [70, 70, 68, 65, 63, 63, 60, 60, 60, 58, 50, 50, 50, 50, 50, 50, 40, 40, 40, 38, 30, 25, 20, 20, 12], "yaxis": "y2"}],
#                         {"barmode": "overlay", "height": 600, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %%
df_100 = df.loc[df.individual_meta_score <20,:]
df_100 = df_100.replace('TBA', np.nan).dropna(axis=0, how='any')
df_100['release_date'] = pd.to_datetime(df_100['release_date'])

# %%
df_100['date'] = df_100['review_date'] < df_100['release_date']
print(sum(df_100['date'])/df_100.shape[0])
# Out:
# 0.6566104702750666

# %%
df.sample(5)
# Out:
#                 critic_name                             distributor  \
# 161537         Nathan Rabin                            FilmDistrict
# 168197         Claudia Puig                       Columbia Pictures
# 194972            Eric Kohn                            Oscilloscope
# 67563   Christopher Machell  Twentieth Century Fox Film Corporation
# 101728         Mick LaSalle                       Columbia Pictures
#
#         individual_meta_score                    media  metascore  \
# 161537                     33            The A.V. Club         56
# 168197                     75                USA Today         67
# 194972                     75                IndieWire         74
# 67563                      40                  CineVue         48
# 101728                     75  San Francisco Chronicle         55
#
#                            movie_title        release_date review_date  \
# 161537  In the Land of Blood and Honey   December 23, 2011  2011-12-22
# 168197               The Ides of March     October 7, 2011  2011-10-06
# 194972                   Lost in Paris       June 16, 2017  2017-05-22
# 67563                     The Predator  September 14, 2018  2018-09-13
# 101728                      Concussion   December 25, 2015  2015-12-23
#
#                                                      text userscore
# 161537  shuddering earnestness fevered good intentions...       3.2
# 168197  political scandals standard fare hinges sex po...       7.1
# 194972  pair blends storybook visuals stream clever ga...       5.7
# 67563   begins intriguing premise gradually squandered...       4.4
# 101728  writerdirector peter landesman fascinating app...       6.2
